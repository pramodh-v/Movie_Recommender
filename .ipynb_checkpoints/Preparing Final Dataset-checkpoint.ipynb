# %%
import pandas as pd
import numpy as np

# %%
d1 = pd.read_csv('movie_2016.csv')
d1 = d1.drop(columns=['Unnamed: 0'])
d1.head(10)
# Out:
#             director     actor_1_name       actor_2_name  \
# 0      James Cameron      CCH Pounder   Joel David Moore
# 1     Gore Verbinski      Johnny Depp      Orlando Bloom
# 2         Sam Mendes  Christoph Waltz       Rory Kinnear
# 3  Christopher Nolan        Tom Hardy     Christian Bale
# 4        Doug Walker      Doug Walker         Rob Walker
# 5     Andrew Stanton     Daryl Sabara    Samantha Morton
# 6          Sam Raimi     J.K. Simmons       James Franco
# 7       Nathan Greno     Brad Garrett       Donna Murphy
# 8        Joss Whedon  Chris Hemsworth  Robert Downey Jr.
# 9        David Yates     Alan Rickman   Daniel Radcliffe
#
#            actor_3_name                                             genres  \
# 0             Wes Studi                    Action Adventure Fantasy Sci-Fi
# 1        Jack Davenport                           Action Adventure Fantasy
# 2      Stephanie Sigman                          Action Adventure Thriller
# ...

# %%
d2 = pd.read_csv('movies_2017.csv')
d2.head(10)
# Out:
#                          director      actor_1_name     actor_2_name  \
# 0  Joachim Rønning Espen Sandberg       Johnny Depp    Javier Bardem
# 1                     Zack Snyder       Ben Affleck     Henry Cavill
# 2                   Taika Waititi   Chris Hemsworth   Tom Hiddleston
# 3                      James Gunn       Chris Pratt      Zoe Saldana
# 4                   Sean McNamara    Pierce Brosnan     William Hurt
# 5                     Adam Spinks   Ben Loyd-Holmes        Sarah Mac
# 6               Rucha Humnabadkar         Ali Fazal  Melanie Chandra
# 7                Sarik Andreasyan  Anton Pampushnyy  Sanzhar Madiyev
# 8                 Peter Hutchings  Victoria Justice        Eden Sher
# 9                   Patty Jenkins         Gal Gadot       Chris Pine
#
#       actor_3_name                            genres  \
# 0    Geoffrey Rush  Adventure Action Fantasy Comedy
# 1        Gal Gadot  Action Adventure Fantasy Sci-Fi
# ...

# %%
d3 = pd.read_csv('movies_2018-2020.csv')
d3 = d3.drop('Unnamed: 0',axis=1)
d3.head()
# Out:
#              director          actor_1_name         actor_2_name  \
# 0        Orson Welles           John Huston            Oja Kodar
# 1       Ramin Bahrani     Michael B. Jordan          Aaron Davis
# 2       Edward Norton         Edward Norton      Gugu Mbatha-Raw
# 3  Sam Taylor-Johnson  Aaron Taylor-Johnson   Billy Bob Thornton
# 4    Robert Rodriguez          Rosa Salazar      Christoph Waltz
#
#          actor_3_name                     genres  \
# 0   Peter Bogdanovich                      Drama
# 1          Cindy Katz    Drama  Sci-Fi  Thriller
# 2        Alec Baldwin      Crime  Drama  Mystery
# 3        Odessa Young                      Drama
# 4   Jennifer Connelly  Action  Adventure  Sci-Fi
#
#                                     movie_title
# 0                      L'altra faccia del vento
# 1                                Fahrenheit 451
# 2  Motherless Brooklyn - I segreti di una città
# 3                       A Million Little Pieces
# ...

# %%
d2 = d2.append(d3)

# %%
d1 = d1.append(d2)

# %%
d1.head(20)
# Out:
#              director        actor_1_name          actor_2_name  \
# 0       James Cameron         CCH Pounder      Joel David Moore
# 1      Gore Verbinski         Johnny Depp         Orlando Bloom
# 2          Sam Mendes     Christoph Waltz          Rory Kinnear
# 3   Christopher Nolan           Tom Hardy        Christian Bale
# 4         Doug Walker         Doug Walker            Rob Walker
# 5      Andrew Stanton        Daryl Sabara       Samantha Morton
# 6           Sam Raimi        J.K. Simmons          James Franco
# 7        Nathan Greno        Brad Garrett          Donna Murphy
# 8         Joss Whedon     Chris Hemsworth     Robert Downey Jr.
# 9         David Yates        Alan Rickman      Daniel Radcliffe
# 10        Zack Snyder        Henry Cavill          Lauren Cohan
# 11       Bryan Singer        Kevin Spacey         Marlon Brando
# 12       Marc Forster  Giancarlo Giannini       Mathieu Amalric
# 13     Gore Verbinski         Johnny Depp         Orlando Bloom
# ...

# %%
d1
# Out:
#                 director             actor_1_name        actor_2_name  \
# 0          James Cameron              CCH Pounder    Joel David Moore
# 1         Gore Verbinski              Johnny Depp       Orlando Bloom
# 2             Sam Mendes          Christoph Waltz        Rory Kinnear
# 3      Christopher Nolan                Tom Hardy      Christian Bale
# 4            Doug Walker              Doug Walker          Rob Walker
# ...                  ...                      ...                 ...
# 1120  Vasilije Nikitovic            Milos Samolov   Boris Milivojevic
# 1121    Marco Pontecorvo       Joaquim de Almeida       Goran Visnjic
# 1122      Cameron Nugent             J.K. Simmons        Keanu Wilson
# 1123  Patrick Cunningham  Monique Gabriela Curnen         Kathy Baker
# 1124  Philippe Falardeau         Margaret Qualley    Sigourney Weaver
#
#                   actor_3_name                           genres  \
# ...

# %%
d1['combined'] = d1['actor_1_name']+' '+d1['actor_2_name']+' '+d1['actor_3_name']+' '+d1['director']+' '+d1['genres']

# %%
d1.head(20)
# Out:
#              director        actor_1_name          actor_2_name  \
# 0       James Cameron         CCH Pounder      Joel David Moore
# 1      Gore Verbinski         Johnny Depp         Orlando Bloom
# 2          Sam Mendes     Christoph Waltz          Rory Kinnear
# 3   Christopher Nolan           Tom Hardy        Christian Bale
# 4         Doug Walker         Doug Walker            Rob Walker
# 5      Andrew Stanton        Daryl Sabara       Samantha Morton
# 6           Sam Raimi        J.K. Simmons          James Franco
# 7        Nathan Greno        Brad Garrett          Donna Murphy
# 8         Joss Whedon     Chris Hemsworth     Robert Downey Jr.
# 9         David Yates        Alan Rickman      Daniel Radcliffe
# 10        Zack Snyder        Henry Cavill          Lauren Cohan
# 11       Bryan Singer        Kevin Spacey         Marlon Brando
# 12       Marc Forster  Giancarlo Giannini       Mathieu Amalric
# 13     Gore Verbinski         Johnny Depp         Orlando Bloom
# ...

# %%
d1.to_csv('Final_Movie_Data.csv',index=False)
